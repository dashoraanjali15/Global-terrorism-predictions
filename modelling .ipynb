# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
gtd = pd.read_csv('globalterrorismdb_0718dist.csv', encoding = 'ISO-8859-1')
#let's take a look
gtd.head(2)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
#
# [2 rows x 135 columns]

# %%
gtd.shape
# Out:
# (181691, 135)

# %%
gtd.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df_final= gtd.drop(columns=['eventid','approxdate','related', 'resolution','latitude',	'longitude',"individual",'dbsource','extended',
 'INT_LOG',
 'INT_IDEO',
 'INT_MISC',
 'INT_ANY',
 'related',
 'attacktype2_txt','attacktype3_txt',"summary",'targsubtype1_txt','corp1',
 'target2',
 'natlty2',
 'natlty2_txt',
 'targtype3',
 'targtype3_txt',
 'targsubtype3',
 'targsubtype3_txt',
 'corp3',
 'target3',
 'natlty3',
 'natlty3_txt','targsubtype2',
 'targsubtype2_txt',
 'corp2',
 'targsubtype1',
'target1',
'natlty1',
'natlty1_txt','weapsubtype1',
'weapsubtype1_txt','nperps',
 'nperpcap',
 'claimed', 'scite1',
 'scite2',
 'nkillus',
 'nkillter',
 'crit3',
 'doubtterr',
 'nwoundus',
 'nwoundte',
 'property',
  'specificity','vicinity','crit1','crit2','multiple','attacktype1','targtype1','guncertain1','weapdetail','region','country',
 'weaptype1',
 ])

# %%
df_final.isnull().sum()
# Out:
# iyear                      0
# imonth                     0
# iday                       0
# country_txt                0
# region_txt                 0
#                        ...
# hostkidoutcome        170700
# hostkidoutcome_txt    170700
# nreleased             171291
# addnotes              153402
# scite3                138175
# Length: 73, dtype: int64

# %% [markdown]
# Columns with greater than 50% null values will be dropped. The rest of the columns imputation will be attempted.

# %%
for col in df_final.columns:
    print(col, f'{df_final[col].isnull().sum() / df_final.shape[0] * 100} % NULL')
# Out:
# iyear 0.0 % NULL
# imonth 0.0 % NULL
# iday 0.0 % NULL
# country_txt 0.0 % NULL
# region_txt 0.0 % NULL
# provstate 0.23171208260177995 % NULL
# city 0.23886708752772565 % NULL
# location 69.45638474112641 % NULL
# alternative 84.03278093026071 % NULL
# alternative_txt 84.03278093026071 % NULL
# success 0.0 % NULL
# suicide 0.0 % NULL
# attacktype1_txt 0.0 % NULL
# attacktype2 96.52486914596761 % NULL
# attacktype3 99.7644352224381 % NULL
# targtype1_txt 0.0 % NULL
# targtype2 93.86650962348162 % NULL
# targtype2_txt 93.86650962348162 % NULL
# gname 0.0 % NULL
# gsubname 96.75823238355228 % NULL
# gname2 98.89207500646702 % NULL
# gsubname2 99.91193840091144 % NULL
# gname3 99.82167526184567 % NULL
# gsubname3 99.98899230011394 % NULL
# motive 72.17198430301997 % NULL
# guncertain2 98.92399733613662 % NULL
# guncertain3 99.82387680182288 % NULL
# claimmode 89.49700315370602 % NULL
# claimmode_txt 89.49700315370602 % NULL
# claim2 98.95977236076635 % NULL
# ...

# %%
perc = 40.0
min_count =  int(((100-perc)/100)*df_final.shape[0] + 1)
mod_df= df_final.dropna( axis=1,
                thresh=min_count)

# %% [markdown]
# Looking at the unique values in each column gives an idea of which columns to drop and which columns to keep.

# %%
list(mod_df.columns.values)
# Out:
# ['iyear',
#  'imonth',
#  'iday',
#  'country_txt',
#  'region_txt',
#  'provstate',
#  'city',
#  'success',
#  'suicide',
#  'attacktype1_txt',
#  'targtype1_txt',
#  'gname',
#  'weaptype1_txt',
#  'nkill',
#  'nwound',
#  'ishostkid']

# %%
mod_df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city  success  suicide                 attacktype1_txt  \
# 0       NaN  Santo Domingo        1        0                   Assassination
# 1   Federal    Mexico city        1        0     Hostage Taking (Kidnapping)
# 2    Tarlac        Unknown        1        0                   Assassination
# 3    Attica         Athens        1        0               Bombing/Explosion
# 4   Fukouka        Fukouka        1        0  Facility/Infrastructure Attack
#
#                  targtype1_txt                               gname  \
# ...

# %%
mod_df=(mod_df.fillna({'nkill': 0, 'nwound': 0,'ishostkid':0}))

# %%
mod_df.isnull().sum()
# Out:
# iyear                0
# imonth               0
# iday                 0
# country_txt          0
# region_txt           0
# provstate          421
# city               434
# success              0
# suicide              0
# attacktype1_txt      0
# targtype1_txt        0
# gname                0
# weaptype1_txt        0
# nkill                0
# nwound               0
# ishostkid            0
# dtype: int64

# %%
mod_df.dropna()
# Out:
#         iyear  imonth  iday    country_txt                  region_txt  \
# 1        1970       0     0         Mexico               North America
# 2        1970       1     0    Philippines              Southeast Asia
# 3        1970       1     0         Greece              Western Europe
# 4        1970       1     0          Japan                   East Asia
# 5        1970       1     1  United States               North America
# ...       ...     ...   ...            ...                         ...
# 181686   2017      12    31        Somalia          Sub-Saharan Africa
# 181687   2017      12    31          Syria  Middle East & North Africa
# 181688   2017      12    31    Philippines              Southeast Asia
# 181689   2017      12    31          India                  South Asia
# 181690   2017      12    31    Philippines              Southeast Asia
#
#               provstate           city  success  suicide  \
# ...

# %% [markdown]
# Performing

# %%
print("Number of Unique Values in Features")
print("====================================")
for col in mod_df.select_dtypes(include=["object"]).columns:
    print(col, f": {mod_df[col].unique().shape[0]}")
    print("====================================")
# Out:
# Number of Unique Values in Features
# ...
# country_txt : 205
# ...
# region_txt : 12
# ...
# provstate : 2856
# ...
# city : 36675
# ...
# attacktype1_txt : 9
# ...
# targtype1_txt : 22
# ...
# gname : 3537
# ...
# weaptype1_txt : 12
# ...

# %%
mod_df['casualities']=mod_df['nkill']+mod_df['nwound']

# %%
# Import label encoder
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
mod_df['provstate']=label_encoder.fit_transform(mod_df['provstate'])
mod_df['city']= label_encoder.fit_transform(mod_df['city'])
mod_df['weaptype1_txt']= label_encoder.fit_transform(mod_df['weaptype1_txt'])
mod_df['targtype1_txt']= label_encoder.fit_transform(mod_df['targtype1_txt'])
mod_df['gname']= label_encoder.fit_transform(mod_df['gname'])
mod_df['region_txt']= label_encoder.fit_transform(mod_df['region_txt'])
mod_df['country_txt']= label_encoder.fit_transform(mod_df['country_txt'])
mod_df['attacktype1_txt']= label_encoder.fit_transform(mod_df['attacktype1_txt'])

# %%
# Separating the dependent and independent variables
y =mod_df['attacktype1_txt']
X = mod_df.drop('attacktype1_txt', axis = 1)

# %%
y
# Out:
# 0         1
# 1         6
# 2         1
# 3         2
# 4         3
#          ..
# 181686    0
# 181687    2
# 181688    3
# 181689    2
# 181690    2
# Name: attacktype1_txt, Length: 181691, dtype: int32

# %%
X.isnull().sum()
# Out:
# iyear            0
# imonth           0
# iday             0
# country_txt      0
# region_txt       0
# provstate        0
# city             0
# success          0
# suicide          0
# targtype1_txt    0
# gname            0
# weaptype1_txt    0
# nkill            0
# nwound           0
# ishostkid        0
# casualities      0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE, SelectKBest, f_classif, chi2,mutual_info_classif, SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.multioutput import ClassifierChain

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, LabelEncoder

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (136268, 16)
# (45423, 16)
# (136268,)
# (45423,)

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
preds_train= rf.predict(X_train)
preds_test= rf.predict(X_test)

# %%
print(rf.feature_importances_)
# Out:
# [0.06209155 0.02821046 0.03627681 0.0261432  0.02177019 0.0334579
#  0.03739623 0.02034004 0.00608058 0.0514677  0.02609016 0.45513499
#  0.03710255 0.02792755 0.08897768 0.04153241]

# %%
plt.bar(range(len(rf.feature_importances_)), rf.feature_importances_)
plt.show()

# %%
from sklearn.metrics import accuracy_score

# %%
print('\nThe accuracy of random forest Classifier is {}%'.format(accuracy_score(y_test, preds_test)*100))
# Out:
# The accuracy of random forest Classifier is 90.32208352596702%

# %%
print('\nThe accuracy of random forest Classifier is {}%'.format(accuracy_score(y_train, preds_train)*100))
# Out:
# The accuracy of random forest Classifier is 99.94716294361112%

# %%
from xgboost import XGBClassifier

# %%
# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
y_pred = model.predict(X_test)
y_pred_train= model.predict(X_train)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 90.20%

# %%
accuracy = accuracy_score(y_train, y_pred_train)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 92.95%

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
# Create adaboost classifer object
AdaBoostClf = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
model = AdaBoostClf.fit(X_train, y_train)

# %%
#Predict the response for test dataset
y_pred_ada = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_ada)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 80.07%

# %%
y_pred_ada_train=model.predict(X_train)
